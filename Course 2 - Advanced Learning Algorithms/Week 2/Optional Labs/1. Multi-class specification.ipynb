# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)
from lab_utils_multiclass_TF import *
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %%
# make 4-class dataset for classification
classes = 4
m = 100
centers = [[-5, 2], [-2, -2], [1, 2], [5, -2]]
std = 1.0
X_train, y_train = make_blobs(n_samples=m, centers=centers, cluster_std=std,random_state=30)

# %%
plt_mc(X_train,y_train,classes, centers, std=std)
# Out:
# D:\5. Machine Learning\ML Specialization Course\ML-Specialization-Course\Course 2 - Advanced Learning Algorithms\Week 2\Optional Labs\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# show classes in data set
print(f"unique classes {np.unique(y_train)}")
# show how classes are represented
print(f"class representation {y_train[:10]}")
# show shapes of our dataset
print(f"shape of X_train: {X_train.shape}, shape of y_train: {y_train.shape}")
# Out:
# unique classes [0 1 2 3]
# class representation [3 3 3 0 3 3 3 3 2 0]
# shape of X_train: (100, 2), shape of y_train: (100,)

# %%
tf.random.set_seed(1234)  # applied to achieve consistent results
model = Sequential(
    [
        Dense(2, activation = 'relu',   name = "L1"),
        Dense(4, activation = 'linear', name = "L2")
    ]
)

# %%
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X_train,y_train,
    epochs=200
)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 5ms/step - loss: 2.8962
# Epoch 2/200
# 4/4 [==============================] - 0s 4ms/step - loss: 2.5961
# Epoch 3/200
# 4/4 [==============================] - 0s 4ms/step - loss: 2.3355
# Epoch 4/200
# 4/4 [==============================] - 0s 4ms/step - loss: 2.1200
# Epoch 5/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9436
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.7692
# Epoch 7/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.6351
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.5122
# Epoch 9/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4157
# Epoch 10/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3169
# Epoch 11/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2392
# Epoch 12/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1730
# Epoch 13/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.1184
# Epoch 14/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0669
# Epoch 15/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0179
# Epoch 16/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9773
# Epoch 17/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9384
# Epoch 18/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8998
# Epoch 19/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8676
# Epoch 20/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8325
# Epoch 21/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8038
# Epoch 22/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7715
# Epoch 23/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7460
# Epoch 24/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7242
# Epoch 25/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7028
# Epoch 26/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6866
# Epoch 27/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6711
# Epoch 28/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6571
# Epoch 29/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6431
# Epoch 30/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6304
# Epoch 31/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6184
# Epoch 32/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6072
# Epoch 33/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5961
# Epoch 34/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5863
# Epoch 35/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5764
# Epoch 36/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5675
# Epoch 37/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5584
# Epoch 38/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5498
# Epoch 39/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5417
# Epoch 40/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5339
# Epoch 41/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5264
# Epoch 42/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5195
# Epoch 43/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5130
# Epoch 44/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5064
# Epoch 45/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5003
# Epoch 46/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4952
# Epoch 47/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4896
# Epoch 48/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4841
# Epoch 49/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4783
# Epoch 50/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4730
# Epoch 51/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4681
# Epoch 52/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4627
# Epoch 53/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4595
# Epoch 54/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4550
# Epoch 55/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4502
# Epoch 56/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4451
# Epoch 57/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4402
# Epoch 58/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4363
# Epoch 59/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4331
# Epoch 60/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4291
# Epoch 61/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4252
# Epoch 62/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4213
# Epoch 63/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4178
# Epoch 64/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4135
# Epoch 65/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4101
# Epoch 66/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4063
# Epoch 67/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4029
# Epoch 68/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3991
# Epoch 69/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3956
# Epoch 70/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3926
# Epoch 71/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3895
# Epoch 72/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3869
# Epoch 73/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3840
# Epoch 74/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3813
# Epoch 75/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3785
# Epoch 76/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3752
# Epoch 77/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3723
# Epoch 78/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3696
# Epoch 79/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3663
# Epoch 80/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3636
# Epoch 81/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3611
# Epoch 82/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3582
# Epoch 83/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3556
# Epoch 84/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3531
# Epoch 85/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3500
# Epoch 86/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3481
# Epoch 87/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3456
# Epoch 88/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3430
# Epoch 89/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3403
# Epoch 90/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3381
# Epoch 91/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3354
# Epoch 92/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3332
# Epoch 93/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3310
# Epoch 94/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3286
# Epoch 95/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3261
# Epoch 96/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3239
# Epoch 97/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3214
# Epoch 98/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3192
# Epoch 99/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3176
# Epoch 100/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3150
# Epoch 101/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3132
# Epoch 102/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3113
# Epoch 103/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3092
# Epoch 104/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3067
# Epoch 105/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3048
# Epoch 106/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3036
# Epoch 107/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3011
# Epoch 108/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2992
# Epoch 109/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2972
# Epoch 110/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2955
# Epoch 111/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2938
# Epoch 112/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2922
# Epoch 113/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2910
# Epoch 114/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2902
# Epoch 115/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2884
# Epoch 116/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2862
# Epoch 117/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2834
# Epoch 118/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2808
# Epoch 119/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2789
# Epoch 120/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2760
# Epoch 121/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2745
# Epoch 122/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2723
# Epoch 123/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2696
# Epoch 124/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2662
# Epoch 125/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2618
# Epoch 126/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2573
# Epoch 127/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2524
# Epoch 128/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2471
# Epoch 129/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2422
# Epoch 130/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2381
# Epoch 131/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2336
# Epoch 132/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2301
# Epoch 133/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2271
# Epoch 134/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2240
# Epoch 135/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2215
# Epoch 136/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2185
# Epoch 137/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2156
# Epoch 138/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2126
# Epoch 139/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2096
# Epoch 140/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2060
# Epoch 141/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2020
# Epoch 142/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1986
# Epoch 143/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1960
# Epoch 144/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1933
# Epoch 145/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1905
# Epoch 146/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1875
# Epoch 147/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1851
# Epoch 148/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1829
# Epoch 149/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1809
# Epoch 150/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1786
# Epoch 151/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1758
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1735
# Epoch 153/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1708
# Epoch 154/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1686
# Epoch 155/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1655
# Epoch 156/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1624
# Epoch 157/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1584
# Epoch 158/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1544
# Epoch 159/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1523
# Epoch 160/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1505
# Epoch 161/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1494
# Epoch 162/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1474
# Epoch 163/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1458
# Epoch 164/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1437
# Epoch 165/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1421
# Epoch 166/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1404
# Epoch 167/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1389
# Epoch 168/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1376
# Epoch 169/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1360
# Epoch 170/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1347
# Epoch 171/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1335
# Epoch 172/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1322
# Epoch 173/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1317
# Epoch 174/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1307
# Epoch 175/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1296
# Epoch 176/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1276
# Epoch 177/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1267
# Epoch 178/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1251
# Epoch 179/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1261
# Epoch 180/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1253
# Epoch 181/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1235
# Epoch 182/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1216
# Epoch 183/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1200
# Epoch 184/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1191
# Epoch 185/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1178
# Epoch 186/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1170
# Epoch 187/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1155
# Epoch 188/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1151
# Epoch 189/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1149
# Epoch 190/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1152
# Epoch 191/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1146
# Epoch 192/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1142
# Epoch 193/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1131
# Epoch 194/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1116
# Epoch 195/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1098
# Epoch 196/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1091
# Epoch 197/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1079
# Epoch 198/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1070
# Epoch 199/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1068
# Epoch 200/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1060

# %%
plt_cat_mc(X_train, y_train, model, classes)
# Out:
# 184/184 [==============================] - 0s 2ms/step
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the first layer
l1 = model.get_layer("L1")
W1,b1 = l1.get_weights()

# %%
# plot the function of the first layer
plt_layer_relu(X_train, y_train.reshape(-1,), W1, b1, classes)
# Out:
# D:\5. Machine Learning\ML Specialization Course\ML-Specialization-Course\Course 2 - Advanced Learning Algorithms\Week 2\Optional Labs\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# D:\5. Machine Learning\ML Specialization Course\ML-Specialization-Course\Course 2 - Advanced Learning Algorithms\Week 2\Optional Labs\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
# gather the trained parameters from the output layer
l2 = model.get_layer("L2")
W2, b2 = l2.get_weights()
# create the 'new features', the training examples after L1 transformation
Xl2 = np.maximum(0, np.dot(X_train,W1) + b1)

plt_output_layer_linear(Xl2, y_train.reshape(-1,), W2, b2, classes,
                        x0_rng = (-0.25,np.amax(Xl2[:,0])), x1_rng = (-0.25,np.amax(Xl2[:,1])))
# Out:
# D:\5. Machine Learning\ML Specialization Course\ML-Specialization-Course\Course 2 - Advanced Learning Algorithms\Week 2\Optional Labs\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# D:\5. Machine Learning\ML Specialization Course\ML-Specialization-Course\Course 2 - Advanced Learning Algorithms\Week 2\Optional Labs\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# D:\5. Machine Learning\ML Specialization Course\ML-Specialization-Course\Course 2 - Advanced Learning Algorithms\Week 2\Optional Labs\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# D:\5. Machine Learning\ML Specialization Course\ML-Specialization-Course\Course 2 - Advanced Learning Algorithms\Week 2\Optional Labs\lab_utils_multiclass_TF.py:63: UserWarning: No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored
#   ax.scatter(X[idx, 0], X[idx, 1],  marker=m,
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
